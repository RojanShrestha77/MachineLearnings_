# %% [markdown]
# Scikit learn provides many heloer functions to donwload popualr datasets. MNIST is one of them
# the following code fetchest the MNIST dataset:

# %%
from sklearn.datasets immport fetch_openml
mnist = fetch_openml('mnist_784', version= 1)
mnist.keys()
dict_keys(['data', 'target', 'feature_names', 'DESCR', 'details', 'categories', 'url'])

# %%
Datasets loaded by scikitlearn generally have a similar dictionary struucutre , includeding the
